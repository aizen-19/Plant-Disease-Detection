# %%
import os

# %%
os.listdir("/kaggle/input/datasets/vipoooool/new-plant-diseases-dataset")
# Out:
# ['New Plant Diseases Dataset(Augmented)',
#  'new plant diseases dataset(augmented)',
#  'test']

# %%
dataset_path = "/kaggle/input/datasets/vipoooool/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)"
os.listdir(dataset_path)
# Out:
# ['valid', 'train']

# %%
import os

TRAIN_DIR = "/kaggle/input/datasets/vipoooool/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train"
VAL_DIR   = "/kaggle/input/datasets/vipoooool/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid"

train_folders = [f for f in os.listdir(TRAIN_DIR) if os.path.isdir(os.path.join(TRAIN_DIR, f))]
val_folders   = [f for f in os.listdir(VAL_DIR) if os.path.isdir(os.path.join(VAL_DIR, f))]

print("Train folder count :", len(train_folders))
print("Validation folder count :", len(val_folders))

print("\nTrain class names:")
print(train_folders)

print("\nValidation class names:")
print(val_folders)
# Out:
# Train folder count : 38
# Validation folder count : 38
#
# Train class names:
# ['Tomato___Late_blight', 'Tomato___healthy', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Potato___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Tomato___Early_blight', 'Tomato___Septoria_leaf_spot', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Strawberry___Leaf_scorch', 'Peach___healthy', 'Apple___Apple_scab', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Bacterial_spot', 'Apple___Black_rot', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Peach___Bacterial_spot', 'Apple___Cedar_apple_rust', 'Tomato___Target_Spot', 'Pepper,_bell___healthy', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Potato___Late_blight', 'Tomato___Tomato_mosaic_virus', 'Strawberry___healthy', 'Apple___healthy', 'Grape___Black_rot', 'Potato___Early_blight', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Common_rust_', 'Grape___Esca_(Black_Measles)', 'Raspberry___healthy', 'Tomato___Leaf_Mold', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Pepper,_bell___Bacterial_spot', 'Corn_(maize)___healthy']
#
# Validation class names:
# ['Tomato___Late_blight', 'Tomato___healthy', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Potato___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Tomato___Early_blight', 'Tomato___Septoria_leaf_spot', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Strawberry___Leaf_scorch', 'Peach___healthy', 'Apple___Apple_scab', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Bacterial_spot', 'Apple___Black_rot', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Peach___Bacterial_spot', 'Apple___Cedar_apple_rust', 'Tomato___Target_Spot', 'Pepper,_bell___healthy', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Potato___Late_blight', 'Tomato___Tomato_mosaic_virus', 'Strawberry___healthy', 'Apple___healthy', 'Grape___Black_rot', 'Potato___Early_blight', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Common_rust_', 'Grape___Esca_(Black_Measles)', 'Raspberry___healthy', 'Tomato___Leaf_Mold', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Pepper,_bell___Bacterial_spot', 'Corn_(maize)___healthy']

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
# Out:
# 2026-04-06 18:02:06.369584: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775498526.744881      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775498526.861878      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775498527.760321      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775498527.760360      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775498527.760363      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775498527.760366      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
import tensorflow as tf

# Mixed Precision (for faster training)
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# Constants
IMG_SIZE = 192
BATCH_SIZE = 16
EPOCHS = 75

# Dataset paths
train_dir = "/kaggle/input/datasets/vipoooool/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train"
val_dir   = "/kaggle/input/datasets/vipoooool/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid"

# Load datasets
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical"
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical"
)

# Class info
class_names = train_ds.class_names
num_classes = len(class_names)

# AUTOTUNE for performance
AUTOTUNE = tf.data.AUTOTUNE

# Shuffle training data
# Prefetch (performance optimization)
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
# Out:
# Found 70295 files belonging to 38 classes.
# I0000 00:00:1775498637.690970      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1775498637.696960      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 17572 files belonging to 38 classes.

# %%
data_aug = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
    layers.RandomTranslation(0.1, 0.1),
])

base_model = tf.keras.applications.EfficientNetB3(
    include_top=False,
    weights="imagenet",
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False

inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_aug(inputs)
x = tf.keras.applications.efficientnet.preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dense(256, activation='relu')(x) 
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(num_classes, activation="softmax", dtype='float32')(x)

model = Model(inputs, outputs)

model.compile(
    optimizer=Adam(learning_rate=3e-4),
    loss=CategoricalCrossentropy(label_smoothing=0.1),
    metrics=[
         "accuracy",
          tf.keras.metrics.Precision(name="prec"),
          tf.keras.metrics.Recall(name="rec")
     ]
)

callbacks = [
    EarlyStopping(patience=5, restore_best_weights=True),
    ReduceLROnPlateau(patience=3, factor=0.3),
    ModelCheckpoint("best_model.keras", save_best_only=True)
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/75
# I0000 00:00:1775498716.307429     130 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 421s 75ms/step - accuracy: 0.5776 - loss: 2.0467 - prec: 0.7945 - rec: 0.4204 - val_accuracy: 0.9017 - val_loss: 1.0930 - val_prec: 0.9604 - val_rec: 0.8186 - learning_rate: 3.0000e-04
# Epoch 2/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 331s 73ms/step - accuracy: 0.8236 - loss: 1.3119 - prec: 0.9295 - rec: 0.6747 - val_accuracy: 0.9124 - val_loss: 1.0624 - val_prec: 0.9618 - val_rec: 0.8404 - learning_rate: 3.0000e-04
# Epoch 3/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 335s 73ms/step - accuracy: 0.8496 - loss: 1.2398 - prec: 0.9427 - rec: 0.7076 - val_accuracy: 0.9171 - val_loss: 1.0474 - val_prec: 0.9608 - val_rec: 0.8541 - learning_rate: 3.0000e-04
# Epoch 4/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 332s 73ms/step - accuracy: 0.8661 - loss: 1.1978 - prec: 0.9477 - rec: 0.7300 - val_accuracy: 0.9334 - val_loss: 1.0007 - val_prec: 0.9687 - val_rec: 0.8742 - learning_rate: 3.0000e-04
# Epoch 5/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 329s 72ms/step - accuracy: 0.8735 - loss: 1.1777 - prec: 0.9512 - rec: 0.7413 - val_accuracy: 0.9389 - val_loss: 0.9936 - val_prec: 0.9701 - val_rec: 0.8796 - learning_rate: 3.0000e-04
# Epoch 6/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 329s 71ms/step - accuracy: 0.8795 - loss: 1.1600 - prec: 0.9542 - rec: 0.7475 - val_accuracy: 0.9376 - val_loss: 0.9840 - val_prec: 0.9691 - val_rec: 0.8792 - learning_rate: 3.0000e-04
# Epoch 7/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 336s 73ms/step - accuracy: 0.8852 - loss: 1.1449 - prec: 0.9575 - rec: 0.7536 - val_accuracy: 0.9383 - val_loss: 0.9797 - val_prec: 0.9721 - val_rec: 0.8813 - learning_rate: 3.0000e-04
# Epoch 8/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 335s 73ms/step - accuracy: 0.8896 - loss: 1.1342 - prec: 0.9576 - rec: 0.7599 - val_accuracy: 0.9435 - val_loss: 0.9728 - val_prec: 0.9739 - val_rec: 0.8932 - learning_rate: 3.0000e-04
# Epoch 9/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 335s 73ms/step - accuracy: 0.8932 - loss: 1.1259 - prec: 0.9589 - rec: 0.7656 - val_accuracy: 0.9399 - val_loss: 0.9745 - val_prec: 0.9724 - val_rec: 0.8846 - learning_rate: 3.0000e-04
# Epoch 10/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 336s 73ms/step - accuracy: 0.8913 - loss: 1.1240 - prec: 0.9585 - rec: 0.7637 - val_accuracy: 0.9458 - val_loss: 0.9637 - val_prec: 0.9741 - val_rec: 0.8923 - learning_rate: 3.0000e-04
# Epoch 11/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 337s 74ms/step - accuracy: 0.8954 - loss: 1.1151 - prec: 0.9596 - rec: 0.7689 - val_accuracy: 0.9461 - val_loss: 0.9565 - val_prec: 0.9738 - val_rec: 0.8901 - learning_rate: 3.0000e-04
# Epoch 12/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 336s 73ms/step - accuracy: 0.8972 - loss: 1.1087 - prec: 0.9614 - rec: 0.7745 - val_accuracy: 0.9394 - val_loss: 0.9701 - val_prec: 0.9682 - val_rec: 0.8862 - learning_rate: 3.0000e-04
# Epoch 13/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 333s 73ms/step - accuracy: 0.8976 - loss: 1.1067 - prec: 0.9608 - rec: 0.7710 - val_accuracy: 0.9470 - val_loss: 0.9531 - val_prec: 0.9745 - val_rec: 0.9021 - learning_rate: 3.0000e-04
# Epoch 14/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 327s 72ms/step - accuracy: 0.8993 - loss: 1.1026 - prec: 0.9610 - rec: 0.7766 - val_accuracy: 0.9453 - val_loss: 0.9574 - val_prec: 0.9724 - val_rec: 0.8976 - learning_rate: 3.0000e-04
# Epoch 15/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 330s 73ms/step - accuracy: 0.9018 - loss: 1.0985 - prec: 0.9620 - rec: 0.7791 - val_accuracy: 0.9475 - val_loss: 0.9485 - val_prec: 0.9749 - val_rec: 0.9004 - learning_rate: 3.0000e-04
# Epoch 16/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 327s 72ms/step - accuracy: 0.9035 - loss: 1.0923 - prec: 0.9639 - rec: 0.7834 - val_accuracy: 0.9481 - val_loss: 0.9499 - val_prec: 0.9739 - val_rec: 0.9016 - learning_rate: 3.0000e-04
# Epoch 17/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 326s 71ms/step - accuracy: 0.9056 - loss: 1.0885 - prec: 0.9624 - rec: 0.7852 - val_accuracy: 0.9470 - val_loss: 0.9565 - val_prec: 0.9731 - val_rec: 0.9018 - learning_rate: 3.0000e-04
# Epoch 18/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 339s 74ms/step - accuracy: 0.9046 - loss: 1.0867 - prec: 0.9646 - rec: 0.7853 - val_accuracy: 0.9503 - val_loss: 0.9442 - val_prec: 0.9763 - val_rec: 0.9030 - learning_rate: 3.0000e-04
# Epoch 19/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 335s 74ms/step - accuracy: 0.9084 - loss: 1.0862 - prec: 0.9660 - rec: 0.7855 - val_accuracy: 0.9501 - val_loss: 0.9466 - val_prec: 0.9755 - val_rec: 0.9048 - learning_rate: 3.0000e-04
# Epoch 20/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 335s 74ms/step - accuracy: 0.9084 - loss: 1.0818 - prec: 0.9664 - rec: 0.7900 - val_accuracy: 0.9513 - val_loss: 0.9368 - val_prec: 0.9759 - val_rec: 0.9048 - learning_rate: 3.0000e-04
# Epoch 21/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 335s 73ms/step - accuracy: 0.9082 - loss: 1.0828 - prec: 0.9645 - rec: 0.7876 - val_accuracy: 0.9513 - val_loss: 0.9476 - val_prec: 0.9772 - val_rec: 0.9043 - learning_rate: 3.0000e-04
# Epoch 22/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 332s 73ms/step - accuracy: 0.9104 - loss: 1.0817 - prec: 0.9661 - rec: 0.7886 - val_accuracy: 0.9520 - val_loss: 0.9399 - val_prec: 0.9772 - val_rec: 0.9031 - learning_rate: 3.0000e-04
# Epoch 23/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 335s 72ms/step - accuracy: 0.9121 - loss: 1.0741 - prec: 0.9671 - rec: 0.7934 - val_accuracy: 0.9517 - val_loss: 0.9394 - val_prec: 0.9760 - val_rec: 0.9081 - learning_rate: 3.0000e-04
# Epoch 24/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 326s 71ms/step - accuracy: 0.9151 - loss: 1.0646 - prec: 0.9682 - rec: 0.7936 - val_accuracy: 0.9562 - val_loss: 0.9228 - val_prec: 0.9785 - val_rec: 0.9132 - learning_rate: 9.0000e-05
# Epoch 25/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 328s 71ms/step - accuracy: 0.9176 - loss: 1.0524 - prec: 0.9709 - rec: 0.8056 - val_accuracy: 0.9554 - val_loss: 0.9209 - val_prec: 0.9785 - val_rec: 0.9154 - learning_rate: 9.0000e-05
# Epoch 26/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 327s 71ms/step - accuracy: 0.9207 - loss: 1.0457 - prec: 0.9705 - rec: 0.8066 - val_accuracy: 0.9577 - val_loss: 0.9167 - val_prec: 0.9788 - val_rec: 0.9112 - learning_rate: 9.0000e-05
# Epoch 27/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 330s 72ms/step - accuracy: 0.9210 - loss: 1.0442 - prec: 0.9706 - rec: 0.8056 - val_accuracy: 0.9552 - val_loss: 0.9163 - val_prec: 0.9777 - val_rec: 0.9154 - learning_rate: 9.0000e-05
# Epoch 28/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 327s 71ms/step - accuracy: 0.9231 - loss: 1.0389 - prec: 0.9707 - rec: 0.8081 - val_accuracy: 0.9566 - val_loss: 0.9184 - val_prec: 0.9790 - val_rec: 0.9158 - learning_rate: 9.0000e-05
# Epoch 29/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 328s 71ms/step - accuracy: 0.9230 - loss: 1.0408 - prec: 0.9707 - rec: 0.8085 - val_accuracy: 0.9563 - val_loss: 0.9172 - val_prec: 0.9791 - val_rec: 0.9158 - learning_rate: 9.0000e-05
# Epoch 30/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 327s 71ms/step - accuracy: 0.9226 - loss: 1.0358 - prec: 0.9710 - rec: 0.8102 - val_accuracy: 0.9584 - val_loss: 0.9145 - val_prec: 0.9794 - val_rec: 0.9182 - learning_rate: 9.0000e-05
# Epoch 31/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 327s 71ms/step - accuracy: 0.9236 - loss: 1.0384 - prec: 0.9718 - rec: 0.8067 - val_accuracy: 0.9596 - val_loss: 0.9085 - val_prec: 0.9791 - val_rec: 0.9209 - learning_rate: 9.0000e-05
# Epoch 32/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 326s 71ms/step - accuracy: 0.9238 - loss: 1.0366 - prec: 0.9726 - rec: 0.8096 - val_accuracy: 0.9586 - val_loss: 0.9113 - val_prec: 0.9785 - val_rec: 0.9207 - learning_rate: 9.0000e-05
# Epoch 33/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 333s 72ms/step - accuracy: 0.9239 - loss: 1.0344 - prec: 0.9713 - rec: 0.8126 - val_accuracy: 0.9606 - val_loss: 0.9067 - val_prec: 0.9804 - val_rec: 0.9204 - learning_rate: 9.0000e-05
# Epoch 34/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 335s 73ms/step - accuracy: 0.9229 - loss: 1.0332 - prec: 0.9717 - rec: 0.8118 - val_accuracy: 0.9603 - val_loss: 0.9068 - val_prec: 0.9807 - val_rec: 0.9204 - learning_rate: 9.0000e-05
# Epoch 35/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 330s 72ms/step - accuracy: 0.9248 - loss: 1.0323 - prec: 0.9739 - rec: 0.8151 - val_accuracy: 0.9610 - val_loss: 0.9060 - val_prec: 0.9814 - val_rec: 0.9203 - learning_rate: 9.0000e-05
# Epoch 36/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 327s 71ms/step - accuracy: 0.9253 - loss: 1.0311 - prec: 0.9729 - rec: 0.8130 - val_accuracy: 0.9596 - val_loss: 0.9065 - val_prec: 0.9797 - val_rec: 0.9184 - learning_rate: 9.0000e-05
# Epoch 37/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 331s 72ms/step - accuracy: 0.9257 - loss: 1.0293 - prec: 0.9731 - rec: 0.8146 - val_accuracy: 0.9604 - val_loss: 0.9054 - val_prec: 0.9807 - val_rec: 0.9215 - learning_rate: 9.0000e-05
# Epoch 38/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 327s 71ms/step - accuracy: 0.9255 - loss: 1.0325 - prec: 0.9725 - rec: 0.8129 - val_accuracy: 0.9589 - val_loss: 0.9092 - val_prec: 0.9800 - val_rec: 0.9183 - learning_rate: 9.0000e-05
# Epoch 39/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 332s 73ms/step - accuracy: 0.9258 - loss: 1.0317 - prec: 0.9727 - rec: 0.8124 - val_accuracy: 0.9606 - val_loss: 0.9014 - val_prec: 0.9805 - val_rec: 0.9204 - learning_rate: 9.0000e-05
# Epoch 40/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 332s 73ms/step - accuracy: 0.9235 - loss: 1.0350 - prec: 0.9723 - rec: 0.8114 - val_accuracy: 0.9590 - val_loss: 0.9069 - val_prec: 0.9799 - val_rec: 0.9194 - learning_rate: 9.0000e-05
# Epoch 41/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 329s 72ms/step - accuracy: 0.9264 - loss: 1.0251 - prec: 0.9732 - rec: 0.8165 - val_accuracy: 0.9598 - val_loss: 0.9036 - val_prec: 0.9807 - val_rec: 0.9215 - learning_rate: 9.0000e-05
# Epoch 42/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 329s 72ms/step - accuracy: 0.9256 - loss: 1.0269 - prec: 0.9738 - rec: 0.8151 - val_accuracy: 0.9597 - val_loss: 0.9053 - val_prec: 0.9796 - val_rec: 0.9224 - learning_rate: 9.0000e-05
# Epoch 43/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 329s 72ms/step - accuracy: 0.9274 - loss: 1.0273 - prec: 0.9724 - rec: 0.8151 - val_accuracy: 0.9611 - val_loss: 0.9021 - val_prec: 0.9806 - val_rec: 0.9220 - learning_rate: 2.7000e-05
# Epoch 44/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 330s 72ms/step - accuracy: 0.9293 - loss: 1.0225 - prec: 0.9743 - rec: 0.8181 - val_accuracy: 0.9610 - val_loss: 0.9013 - val_prec: 0.9809 - val_rec: 0.9224 - learning_rate: 2.7000e-05
# Epoch 45/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 340s 74ms/step - accuracy: 0.9305 - loss: 1.0185 - prec: 0.9765 - rec: 0.8206 - val_accuracy: 0.9619 - val_loss: 0.8990 - val_prec: 0.9811 - val_rec: 0.9246 - learning_rate: 2.7000e-05
# Epoch 46/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 334s 73ms/step - accuracy: 0.9294 - loss: 1.0191 - prec: 0.9754 - rec: 0.8198 - val_accuracy: 0.9608 - val_loss: 0.9026 - val_prec: 0.9801 - val_rec: 0.9238 - learning_rate: 2.7000e-05
# Epoch 47/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 335s 73ms/step - accuracy: 0.9286 - loss: 1.0217 - prec: 0.9743 - rec: 0.8170 - val_accuracy: 0.9606 - val_loss: 0.9021 - val_prec: 0.9811 - val_rec: 0.9206 - learning_rate: 2.7000e-05
# Epoch 48/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 336s 73ms/step - accuracy: 0.9286 - loss: 1.0173 - prec: 0.9744 - rec: 0.8243 - val_accuracy: 0.9618 - val_loss: 0.8992 - val_prec: 0.9811 - val_rec: 0.9234 - learning_rate: 2.7000e-05
# Epoch 49/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 333s 73ms/step - accuracy: 0.9305 - loss: 1.0172 - prec: 0.9756 - rec: 0.8205 - val_accuracy: 0.9616 - val_loss: 0.8975 - val_prec: 0.9813 - val_rec: 0.9246 - learning_rate: 8.1000e-06
# Epoch 50/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 337s 74ms/step - accuracy: 0.9299 - loss: 1.0164 - prec: 0.9751 - rec: 0.8184 - val_accuracy: 0.9622 - val_loss: 0.8972 - val_prec: 0.9808 - val_rec: 0.9254 - learning_rate: 8.1000e-06
# Epoch 52/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 337s 74ms/step - accuracy: 0.9294 - loss: 1.0173 - prec: 0.9743 - rec: 0.8194 - val_accuracy: 0.9618 - val_loss: 0.8963 - val_prec: 0.9816 - val_rec: 0.9251 - learning_rate: 8.1000e-06
# Epoch 53/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 335s 73ms/step - accuracy: 0.9321 - loss: 1.0141 - prec: 0.9751 - rec: 0.8232 - val_accuracy: 0.9614 - val_loss: 0.8996 - val_prec: 0.9809 - val_rec: 0.9232 - learning_rate: 8.1000e-06
# Epoch 54/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 328s 71ms/step - accuracy: 0.9309 - loss: 1.0151 - prec: 0.9742 - rec: 0.8206 - val_accuracy: 0.9611 - val_loss: 0.8979 - val_prec: 0.9812 - val_rec: 0.9233 - learning_rate: 8.1000e-06
# Epoch 55/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 329s 72ms/step - accuracy: 0.9311 - loss: 1.0135 - prec: 0.9764 - rec: 0.8226 - val_accuracy: 0.9606 - val_loss: 0.8986 - val_prec: 0.9806 - val_rec: 0.9253 - learning_rate: 8.1000e-06
# Epoch 56/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 327s 72ms/step - accuracy: 0.9311 - loss: 1.0171 - prec: 0.9740 - rec: 0.8202 - val_accuracy: 0.9606 - val_loss: 0.9002 - val_prec: 0.9802 - val_rec: 0.9240 - learning_rate: 2.4300e-06
# Epoch 57/75
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 327s 72ms/step - accuracy: 0.9315 - loss: 1.0174 - prec: 0.9743 - rec: 0.8212 - val_accuracy: 0.9611 - val_loss: 0.9006 - val_prec: 0.9811 - val_rec: 0.9241 - learning_rate: 2.4300e-06

# %%
# Unfreeze more layers
for layer in base_model.layers:
    layer.trainable = True

# Keep BatchNorm frozen (important)
for layer in base_model.layers:
    if isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = False

# Compile with BETTER learning rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),  # 🔥 increased
    loss=tf.keras.losses.CategoricalCrossentropy(),          # ❌ removed smoothing
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(name="prec"),
        tf.keras.metrics.Recall(name="rec")
    ]
)

# Train
history_fine = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15,   # enough when LR is higher
    callbacks=callbacks
)

# Save
model.save("plant_disease_model.keras")
# Out:
# Epoch 1/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 890s 182ms/step - accuracy: 0.9746 - loss: 0.0890 - prec: 0.9792 - rec: 0.9697 - val_accuracy: 0.9859 - val_loss: 0.0463 - val_prec: 0.9869 - val_rec: 0.9852 - learning_rate: 1.0000e-04
# Epoch 2/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 768s 172ms/step - accuracy: 0.9854 - loss: 0.0486 - prec: 0.9876 - rec: 0.9838 - val_accuracy: 0.9882 - val_loss: 0.0407 - val_prec: 0.9889 - val_rec: 0.9876 - learning_rate: 1.0000e-04
# Epoch 3/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 772s 172ms/step - accuracy: 0.9878 - loss: 0.0404 - prec: 0.9892 - rec: 0.9867 - val_accuracy: 0.9877 - val_loss: 0.0380 - val_prec: 0.9881 - val_rec: 0.9874 - learning_rate: 1.0000e-04
# Epoch 4/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 764s 171ms/step - accuracy: 0.9898 - loss: 0.0319 - prec: 0.9911 - rec: 0.9890 - val_accuracy: 0.9877 - val_loss: 0.0389 - val_prec: 0.9882 - val_rec: 0.9874 - learning_rate: 1.0000e-04
# Epoch 5/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 789s 177ms/step - accuracy: 0.9906 - loss: 0.0324 - prec: 0.9915 - rec: 0.9898 - val_accuracy: 0.9913 - val_loss: 0.0306 - val_prec: 0.9916 - val_rec: 0.9909 - learning_rate: 1.0000e-04
# Epoch 6/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 777s 173ms/step - accuracy: 0.9921 - loss: 0.0246 - prec: 0.9927 - rec: 0.9915 - val_accuracy: 0.9935 - val_loss: 0.0193 - val_prec: 0.9940 - val_rec: 0.9931 - learning_rate: 1.0000e-04
# Epoch 7/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 745s 166ms/step - accuracy: 0.9914 - loss: 0.0290 - prec: 0.9919 - rec: 0.9906 - val_accuracy: 0.9928 - val_loss: 0.0238 - val_prec: 0.9933 - val_rec: 0.9927 - learning_rate: 1.0000e-04
# Epoch 8/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 755s 167ms/step - accuracy: 0.9934 - loss: 0.0229 - prec: 0.9939 - rec: 0.9929 - val_accuracy: 0.9968 - val_loss: 0.0119 - val_prec: 0.9968 - val_rec: 0.9966 - learning_rate: 1.0000e-04
# Epoch 9/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 749s 167ms/step - accuracy: 0.9936 - loss: 0.0213 - prec: 0.9941 - rec: 0.9932 - val_accuracy: 0.9920 - val_loss: 0.0273 - val_prec: 0.9923 - val_rec: 0.9919 - learning_rate: 1.0000e-04
# Epoch 10/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 748s 167ms/step - accuracy: 0.9933 - loss: 0.0211 - prec: 0.9939 - rec: 0.9928 - val_accuracy: 0.9937 - val_loss: 0.0237 - val_prec: 0.9938 - val_rec: 0.9936 - learning_rate: 1.0000e-04
# Epoch 11/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 749s 167ms/step - accuracy: 0.9937 - loss: 0.0214 - prec: 0.9942 - rec: 0.9931 - val_accuracy: 0.9936 - val_loss: 0.0229 - val_prec: 0.9936 - val_rec: 0.9935 - learning_rate: 1.0000e-04
# Epoch 12/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 749s 167ms/step - accuracy: 0.9977 - loss: 0.0072 - prec: 0.9980 - rec: 0.9975 - val_accuracy: 0.9973 - val_loss: 0.0094 - val_prec: 0.9974 - val_rec: 0.9973 - learning_rate: 3.0000e-05
# Epoch 13/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 749s 167ms/step - accuracy: 0.9983 - loss: 0.0053 - prec: 0.9983 - rec: 0.9982 - val_accuracy: 0.9985 - val_loss: 0.0059 - val_prec: 0.9985 - val_rec: 0.9985 - learning_rate: 3.0000e-05
# Epoch 14/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 746s 167ms/step - accuracy: 0.9988 - loss: 0.0037 - prec: 0.9988 - rec: 0.9988 - val_accuracy: 0.9977 - val_loss: 0.0074 - val_prec: 0.9977 - val_rec: 0.9977 - learning_rate: 3.0000e-05
# Epoch 15/15
# 4394/4394 ━━━━━━━━━━━━━━━━━━━━ 747s 167ms/step - accuracy: 0.9991 - loss: 0.0037 - prec: 0.9991 - rec: 0.9990 - val_accuracy: 0.9973 - val_loss: 0.0109 - val_prec: 0.9973 - val_rec: 0.9973 - learning_rate: 3.0000e-05

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, classification_report

yt, yp = [], []

for x, y in val_ds:
    p = model.predict(x, verbose=0)
    yt.extend(np.argmax(y.numpy(), axis=1))
    yp.extend(np.argmax(p, axis=1))

# Metrics
f1 = f1_score(yt, yp, average="weighted")
precision = precision_score(yt, yp, average="weighted")
recall = recall_score(yt, yp, average="weighted")

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.9984633654753144
# Precision: 0.9984775081704694
# Recall: 0.9984634646027771

# %%
import matplotlib.pyplot as plt

# BEFORE FINE TUNING
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Accuracy Before Fine Tuning")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train Accuracy", "Validation Accuracy"])
plt.show()


plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Loss Before Fine Tuning")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train Loss", "Validation Loss"])
plt.show()


# AFTER FINE TUNING
plt.figure()
plt.plot(history_fine.history['accuracy'])
plt.plot(history_fine.history['val_accuracy'])
plt.title("Accuracy After Fine Tuning")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train Accuracy", "Validation Accuracy"])
plt.show()


plt.figure()
plt.plot(history_fine.history['loss'])
plt.plot(history_fine.history['val_loss'])
plt.title("Loss After Fine Tuning")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train Loss", "Validation Loss"])
plt.show()

# %%
import tensorflow as tf
import numpy as np

# Load test dataset (no labels)
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode=None,
    shuffle=False
)

# Preprocessing
def preprocess(x):
    x = tf.cast(x, tf.float32)
    x = tf.keras.applications.efficientnet.preprocess_input(x)
    return x

test_ds = test_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
test_ds = test_ds.prefetch(tf.data.AUTOTUNE)

# TTA (Test Time Augmentation)
def predict_with_tta(model, x):
    preds = []
    
    preds.append(model.predict(x, verbose=0))
    preds.append(model.predict(tf.image.flip_left_right(x), verbose=0))
    preds.append(model.predict(tf.image.flip_up_down(x), verbose=0))
    
    return np.mean(preds, axis=0)

# Sharpen predictions (increase confidence)
def sharpen(preds, temp=0.7):
    preds = np.log(preds + 1e-8) / temp
    preds = np.exp(preds)
    return preds / np.sum(preds, axis=1, keepdims=True)

# 🔥 Run predictions + collect confidence
all_conf = []

for x in test_ds:
    preds = predict_with_tta(model, x)
    preds = sharpen(preds)   # apply sharpening
    
    conf = np.max(preds, axis=1)
    all_conf.extend(conf)

#  Mean confidence
mean_conf = np.mean(all_conf)

print(f"\n Boosted Mean Confidence: {mean_conf*100:.2f}%")
# Out:
# Found 252 files.
#
# 🔥 Boosted Mean Confidence: 65.31%

# %%
import tensorflow as tf

# Load dataset WITHOUT labels
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode=None,
    shuffle=False
)

# Add preprocessing + dummy labels
def preprocess_and_add_dummy(x):
    x = tf.keras.applications.efficientnet.preprocess_input(x)
    
    # Dummy labels (same shape as model output)
    dummy_y = tf.zeros((tf.shape(x)[0], len(class_names)))
    
    return x, dummy_y

test_ds = test_ds.map(preprocess_and_add_dummy, num_parallel_calls=tf.data.AUTOTUNE)
test_ds = test_ds.prefetch(tf.data.AUTOTUNE)

# Prediction (works without error)
predictions = model.predict(test_ds)
# Out:
# Found 252 files.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 285ms/step

# %%
for x, _ in test_ds:   # ignore dummy labels
    preds = model.predict(x, verbose=0)

    for i in range(len(preds)):
        top_class = np.argmax(preds[i])
        confidence = np.max(preds[i])

        print(f"Predicted class: {class_names[top_class]}, Confidence: {confidence:.2f}")
# Out:
# Predicted class: Strawberry___Leaf_scorch, Confidence: 1.00
# Predicted class: Apple___Apple_scab, Confidence: 0.99
# Predicted class: Apple___Cedar_apple_rust, Confidence: 1.00
# Predicted class: Potato___Early_blight, Confidence: 0.99
# Predicted class: Potato___Early_blight, Confidence: 1.00
# Predicted class: Apple___Apple_scab, Confidence: 0.99
# Predicted class: Apple___healthy, Confidence: 0.94
# Predicted class: Apple___healthy, Confidence: 0.94
# Predicted class: Tomato___Bacterial_spot, Confidence: 0.54
# Predicted class: Strawberry___Leaf_scorch, Confidence: 1.00
# Predicted class: Cherry_(including_sour)___healthy, Confidence: 0.49
# Predicted class: Apple___healthy, Confidence: 1.00
# Predicted class: Pepper,_bell___healthy, Confidence: 0.50
# Predicted class: Raspberry___healthy, Confidence: 0.70
# Predicted class: Apple___healthy, Confidence: 0.84
# Predicted class: Potato___healthy, Confidence: 0.99
# Predicted class: Potato___healthy, Confidence: 0.47
# Predicted class: Strawberry___healthy, Confidence: 0.94
# Predicted class: Grape___healthy, Confidence: 0.63
# Predicted class: Apple___healthy, Confidence: 0.60
# Predicted class: Potato___Early_blight, Confidence: 0.73
# Predicted class: Tomato___Early_blight, Confidence: 0.98
# Predicted class: Apple___Cedar_apple_rust, Confidence: 0.56
# Predicted class: Potato___healthy, Confidence: 0.95
# Predicted class: Apple___Black_rot, Confidence: 0.53
# Predicted class: Strawberry___Leaf_scorch, Confidence: 0.41
# Predicted class: Strawberry___Leaf_scorch, Confidence: 0.93
# Predicted class: Apple___Cedar_apple_rust, Confidence: 0.54
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 0.49
# Predicted class: Pepper,_bell___healthy, Confidence: 0.99
# Predicted class: Potato___healthy, Confidence: 1.00
# Predicted class: Pepper,_bell___healthy, Confidence: 1.00
# Predicted class: Cherry_(including_sour)___healthy, Confidence: 0.27
# Predicted class: Pepper,_bell___healthy, Confidence: 0.93
# Predicted class: Pepper,_bell___healthy, Confidence: 0.99
# Predicted class: Pepper,_bell___healthy, Confidence: 1.00
# Predicted class: Pepper,_bell___healthy, Confidence: 1.00
# Predicted class: Pepper,_bell___Bacterial_spot, Confidence: 0.50
# Predicted class: Pepper,_bell___Bacterial_spot, Confidence: 0.78
# Predicted class: Tomato___Septoria_leaf_spot, Confidence: 0.98
# Predicted class: Pepper,_bell___Bacterial_spot, Confidence: 0.93
# Predicted class: Cherry_(including_sour)___healthy, Confidence: 0.50
# Predicted class: Pepper,_bell___Bacterial_spot, Confidence: 0.90
# Predicted class: Cherry_(including_sour)___healthy, Confidence: 0.50
# Predicted class: Tomato___Early_blight, Confidence: 0.71
# Predicted class: Strawberry___Leaf_scorch, Confidence: 0.54
# Predicted class: Blueberry___healthy, Confidence: 1.00
# Predicted class: Blueberry___healthy, Confidence: 1.00
# Predicted class: Pepper,_bell___healthy, Confidence: 1.00
# Predicted class: Raspberry___healthy, Confidence: 0.48
# Predicted class: Potato___healthy, Confidence: 1.00
# Predicted class: Pepper,_bell___Bacterial_spot, Confidence: 0.96
# Predicted class: Pepper,_bell___Bacterial_spot, Confidence: 0.71
# Predicted class: Strawberry___Leaf_scorch, Confidence: 0.49
# Predicted class: Orange___Haunglongbing_(Citrus_greening), Confidence: 0.72
# Predicted class: Potato___healthy, Confidence: 1.00
# Predicted class: Blueberry___healthy, Confidence: 0.33
# Predicted class: Potato___healthy, Confidence: 0.39
# Predicted class: Blueberry___healthy, Confidence: 1.00
# Predicted class: Pepper,_bell___healthy, Confidence: 0.96
# Predicted class: Peach___healthy, Confidence: 0.72
# Predicted class: Apple___healthy, Confidence: 1.00
# Predicted class: Blueberry___healthy, Confidence: 0.77
# Predicted class: Apple___Cedar_apple_rust, Confidence: 1.00
# Predicted class: Apple___Black_rot, Confidence: 0.83
# Predicted class: Apple___healthy, Confidence: 0.51
# Predicted class: Apple___healthy, Confidence: 0.45
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 1.00
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 1.00
# Predicted class: Corn_(maize)___Northern_Leaf_Blight, Confidence: 1.00
# Predicted class: Corn_(maize)___healthy, Confidence: 0.32
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 0.98
# Predicted class: Corn_(maize)___Common_rust_, Confidence: 0.75
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 1.00
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 1.00
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 1.00
# Predicted class: Corn_(maize)___Northern_Leaf_Blight, Confidence: 1.00
# Predicted class: Corn_(maize)___Northern_Leaf_Blight, Confidence: 1.00
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 1.00
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 0.96
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 0.95
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 1.00
# Predicted class: Corn_(maize)___Northern_Leaf_Blight, Confidence: 1.00
# Predicted class: Corn_(maize)___Northern_Leaf_Blight, Confidence: 0.54
# Predicted class: Corn_(maize)___Northern_Leaf_Blight, Confidence: 0.86
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 0.69
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 0.95
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 0.78
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 0.85
# Predicted class: Corn_(maize)___Northern_Leaf_Blight, Confidence: 0.92
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 0.59
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 0.93
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 0.51
# Predicted class: Potato___healthy, Confidence: 0.30
# Predicted class: Peach___healthy, Confidence: 1.00
# Predicted class: Cherry_(including_sour)___healthy, Confidence: 0.89
# Predicted class: Potato___healthy, Confidence: 0.61
# Predicted class: Peach___healthy, Confidence: 1.00
# Predicted class: Potato___healthy, Confidence: 0.99
# Predicted class: Peach___healthy, Confidence: 1.00
# Predicted class: Potato___healthy, Confidence: 0.94
# Predicted class: Peach___healthy, Confidence: 1.00
# Predicted class: Potato___Early_blight, Confidence: 0.77
# Predicted class: Corn_(maize)___Common_rust_, Confidence: 0.93
# Predicted class: Potato___Early_blight, Confidence: 0.83
# Predicted class: Potato___Late_blight, Confidence: 1.00
# Predicted class: Tomato___Late_blight, Confidence: 0.81
# Predicted class: Potato___Late_blight, Confidence: 0.34
# Predicted class: Tomato___Early_blight, Confidence: 0.51
# Predicted class: Potato___Late_blight, Confidence: 0.97
# Predicted class: Potato___Late_blight, Confidence: 1.00
# Predicted class: Potato___Late_blight, Confidence: 1.00
# Predicted class: Potato___Late_blight, Confidence: 1.00
# Predicted class: Potato___Late_blight, Confidence: 1.00
# Predicted class: Potato___Late_blight, Confidence: 0.97
# Predicted class: Tomato___Early_blight, Confidence: 1.00
# Predicted class: Pepper,_bell___Bacterial_spot, Confidence: 0.59
# Predicted class: Tomato___Late_blight, Confidence: 0.99
# Predicted class: Tomato___Late_blight, Confidence: 1.00
# Predicted class: Potato___Late_blight, Confidence: 0.38
# Predicted class: Potato___healthy, Confidence: 0.98
# Predicted class: Tomato___Late_blight, Confidence: 1.00
# Predicted class: Tomato___Septoria_leaf_spot, Confidence: 0.99
# Predicted class: Tomato___Late_blight, Confidence: 1.00
# Predicted class: Raspberry___healthy, Confidence: 1.00
# Predicted class: Raspberry___healthy, Confidence: 1.00
# Predicted class: Raspberry___healthy, Confidence: 0.61
# Predicted class: Grape___healthy, Confidence: 0.76
# Predicted class: Raspberry___healthy, Confidence: 1.00
# Predicted class: Raspberry___healthy, Confidence: 1.00
# Predicted class: Raspberry___healthy, Confidence: 1.00
# Predicted class: Blueberry___healthy, Confidence: 1.00
# Predicted class: Soybean___healthy, Confidence: 0.39
# Predicted class: Grape___healthy, Confidence: 0.37
# Predicted class: Potato___healthy, Confidence: 1.00
# Predicted class: Grape___Leaf_blight_(Isariopsis_Leaf_Spot), Confidence: 0.62
# Predicted class: Potato___healthy, Confidence: 0.38
# Predicted class: Potato___healthy, Confidence: 0.69
# Predicted class: Blueberry___healthy, Confidence: 1.00
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 0.66
# Predicted class: Tomato___healthy, Confidence: 0.96
# Predicted class: Squash___Powdery_mildew, Confidence: 0.93
# Predicted class: Squash___Powdery_mildew, Confidence: 0.98
# Predicted class: Corn_(maize)___Common_rust_, Confidence: 0.47
# Predicted class: Squash___Powdery_mildew, Confidence: 1.00
# Predicted class: Raspberry___healthy, Confidence: 1.00
# Predicted class: Raspberry___healthy, Confidence: 1.00
# Predicted class: Raspberry___healthy, Confidence: 1.00
# Predicted class: Raspberry___healthy, Confidence: 1.00
# Predicted class: Raspberry___healthy, Confidence: 0.60
# Predicted class: Raspberry___healthy, Confidence: 1.00
# Predicted class: Grape___healthy, Confidence: 0.90
# Predicted class: Raspberry___healthy, Confidence: 0.99
# Predicted class: Tomato___Early_blight, Confidence: 1.00
# Predicted class: Tomato___Early_blight, Confidence: 0.79
# Predicted class: Cherry_(including_sour)___healthy, Confidence: 1.00
# Predicted class: Tomato___Early_blight, Confidence: 1.00
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 0.44
# Predicted class: Tomato___Early_blight, Confidence: 0.94
# Predicted class: Tomato___Early_blight, Confidence: 1.00
# Predicted class: Grape___Black_rot, Confidence: 0.39
# Predicted class: Tomato___Early_blight, Confidence: 0.67
# Predicted class: Tomato___Early_blight, Confidence: 0.45
# Predicted class: Tomato___Target_Spot, Confidence: 0.69
# Predicted class: Tomato___Early_blight, Confidence: 0.82
# Predicted class: Tomato___Early_blight, Confidence: 0.71
# Predicted class: Tomato___Bacterial_spot, Confidence: 0.92
# Predicted class: Tomato___Bacterial_spot, Confidence: 0.67
# Predicted class: Corn_(maize)___Common_rust_, Confidence: 0.57
# Predicted class: Tomato___Early_blight, Confidence: 0.69
# Predicted class: Tomato___Early_blight, Confidence: 1.00
# Predicted class: Tomato___Early_blight, Confidence: 0.99
# Predicted class: Tomato___Early_blight, Confidence: 0.56
# Predicted class: Tomato___Septoria_leaf_spot, Confidence: 0.55
# Predicted class: Pepper,_bell___healthy, Confidence: 0.90
# Predicted class: Pepper,_bell___healthy, Confidence: 1.00
# Predicted class: Cherry_(including_sour)___healthy, Confidence: 0.66
# Predicted class: Tomato___Tomato_mosaic_virus, Confidence: 0.94
# Predicted class: Tomato___Early_blight, Confidence: 1.00
# Predicted class: Tomato___Spider_mites Two-spotted_spider_mite, Confidence: 0.99
# Predicted class: Tomato___Late_blight, Confidence: 0.78
# Predicted class: Tomato___healthy, Confidence: 1.00
# Predicted class: Tomato___Septoria_leaf_spot, Confidence: 0.90
# Predicted class: Strawberry___Leaf_scorch, Confidence: 0.66
# Predicted class: Pepper,_bell___Bacterial_spot, Confidence: 0.97
# Predicted class: Potato___Early_blight, Confidence: 0.87
# Predicted class: Tomato___Spider_mites Two-spotted_spider_mite, Confidence: 0.65
# Predicted class: Corn_(maize)___Common_rust_, Confidence: 0.96
# Predicted class: Tomato___Septoria_leaf_spot, Confidence: 0.92
# Predicted class: Tomato___Septoria_leaf_spot, Confidence: 0.95
# Predicted class: Strawberry___Leaf_scorch, Confidence: 0.24
# Predicted class: Tomato___Late_blight, Confidence: 1.00
# Predicted class: Tomato___Late_blight, Confidence: 0.91
# Predicted class: Tomato___Early_blight, Confidence: 0.71
# Predicted class: Tomato___Late_blight, Confidence: 0.76
# Predicted class: Tomato___Late_blight, Confidence: 0.65
# Predicted class: Strawberry___Leaf_scorch, Confidence: 0.44
# Predicted class: Tomato___Late_blight, Confidence: 0.96
# Predicted class: Tomato___Early_blight, Confidence: 0.51
# Predicted class: Tomato___Late_blight, Confidence: 1.00
# Predicted class: Tomato___Late_blight, Confidence: 1.00
# Predicted class: Squash___Powdery_mildew, Confidence: 1.00
# Predicted class: Tomato___Early_blight, Confidence: 0.50
# Predicted class: Cherry_(including_sour)___healthy, Confidence: 0.69
# Predicted class: Potato___healthy, Confidence: 0.73
# Predicted class: Tomato___Late_blight, Confidence: 0.84
# Predicted class: Tomato___Spider_mites Two-spotted_spider_mite, Confidence: 0.56
# Predicted class: Tomato___Spider_mites Two-spotted_spider_mite, Confidence: 0.91
# Predicted class: Pepper,_bell___healthy, Confidence: 0.25
# Predicted class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Confidence: 0.37
# Predicted class: Tomato___healthy, Confidence: 0.99
# Predicted class: Tomato___healthy, Confidence: 0.87
# Predicted class: Tomato___Late_blight, Confidence: 0.74
# Predicted class: Tomato___Late_blight, Confidence: 0.99
# Predicted class: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 1.00
# Predicted class: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 1.00
# Predicted class: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 1.00
# Predicted class: Tomato___Late_blight, Confidence: 0.74
# Predicted class: Tomato___Late_blight, Confidence: 0.75
# Predicted class: Tomato___Target_Spot, Confidence: 0.73
# Predicted class: Pepper,_bell___healthy, Confidence: 0.47
# Predicted class: Tomato___Tomato_mosaic_virus, Confidence: 0.63
# Predicted class: Cherry_(including_sour)___healthy, Confidence: 0.90
# Predicted class: Tomato___Late_blight, Confidence: 0.56
# Predicted class: Potato___Early_blight, Confidence: 0.49
# Predicted class: Tomato___Late_blight, Confidence: 0.90
# Predicted class: Cherry_(including_sour)___healthy, Confidence: 0.47
# Predicted class: Tomato___Late_blight, Confidence: 0.99
# Predicted class: Tomato___Late_blight, Confidence: 0.62
# Predicted class: Strawberry___Leaf_scorch, Confidence: 0.28
# Predicted class: Tomato___Tomato_mosaic_virus, Confidence: 0.24
# Predicted class: Tomato___Late_blight, Confidence: 0.85
# Predicted class: Grape___healthy, Confidence: 0.57
# Predicted class: Tomato___Late_blight, Confidence: 0.94
# Predicted class: Grape___healthy, Confidence: 1.00
# Predicted class: Grape___healthy, Confidence: 0.97
# Predicted class: Grape___healthy, Confidence: 1.00
# Predicted class: Grape___Black_rot, Confidence: 0.98
# Predicted class: Grape___healthy, Confidence: 1.00
# Predicted class: Grape___healthy, Confidence: 1.00
# Predicted class: Raspberry___healthy, Confidence: 0.62
# Predicted class: Cherry_(including_sour)___healthy, Confidence: 0.89
# Predicted class: Grape___healthy, Confidence: 1.00
# Predicted class: Grape___Leaf_blight_(Isariopsis_Leaf_Spot), Confidence: 0.73
# Predicted class: Apple___Black_rot, Confidence: 0.67
# Predicted class: Strawberry___Leaf_scorch, Confidence: 0.98
# Predicted class: Grape___healthy, Confidence: 0.99
# Predicted class: Grape___Black_rot, Confidence: 0.96
# Predicted class: Grape___Black_rot, Confidence: 1.00
# Predicted class: Apple___Black_rot, Confidence: 0.81
# Predicted class: Grape___Black_rot, Confidence: 0.28
# Predicted class: Grape___Esca_(Black_Measles), Confidence: 0.44

# %%
import numpy as np

all_confidences = []

for x, _ in test_ds:
    preds = model.predict(x, verbose=0)

    # get max confidence for each image in batch
    conf = np.max(preds, axis=1)
    all_confidences.extend(conf)

# calculate mean
mean_conf = np.mean(all_confidences)

print(f"\nMean Confidence: {mean_conf:.4f}")
# Out:
# Mean Confidence: 0.8065

# %%
import matplotlib.pyplot as plt

classes = list(class_acc.keys())
accuracies = list(class_acc.values())

plt.figure(figsize=(20, 8))
plt.bar(classes, accuracies)

plt.xticks(rotation=90)
plt.ylabel("Accuracy")
plt.xlabel("Classes")
plt.title("Per-Class Accuracy on Test Dataset")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_55/2187036879.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 classes = list(class_acc.keys())
#       4 accuracies = list(class_acc.values())
#       5
#
# NameError: name 'class_acc' is not defined
